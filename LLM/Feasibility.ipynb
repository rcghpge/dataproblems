# %% [markdown]
# # LLM Feasibility

# %% [markdown]
# Feasibility demo from preliminary prototyping does not render on GitHub. See full notebook with Jupyter Notebook Viewer here: [link here](https://nbviewer.org/github/rcghpge/version-llm/blob/main/notebooks/Feasibility.ipynb)

# %% [markdown]
# ## Current Project Structure

# %% [markdown]
# ```bash
# rc@workstation:~/version-sdk/sandbox/dev/version-llm $ tree -L 1
# .
# ├── Dockerfile
# ├── README.md
# ├── __init__.py
# ├── backend
# ├── cli_demo
# ├── devnotes.md
# ├── examples
# ├── frontend
# ├── gui
# ├── main.py
# ├── notebooks
# ├── pixi.lock
# ├── pixi.toml
# └── scripts
#
# 8 directories, 7 files
# ```

# %% [markdown]
# ![llmproject.png](attachment:519f9eb5-9bdc-4b20-a939-488ca72400fa.png)

# %%
from IPython.display import HTML, YouTubeVideo

#YouTubeVideo('eYahofxfriA', width=900, height=550, centered=True, embed=True)
video_id = "eYahofxfriA"  
width = 900
height = 550

llmproject = f"""
<div align="center">
  <iframe width="{width}" height="{height}" src="https://www.youtube.com/embed/{video_id}" frameborder="0" allowfullscreen></iframe>
</div>
"""

display(HTML(llmproject))
# Out:
# <div align="center">
#   <iframe width="900" height="550" src="https://www.youtube.com/embed/eYahofxfriA" frameborder="0" allowfullscreen></iframe>
# </div>

# %%
# is buildable. not a fully robust model but doable.
