# %%
# Robert Cocker
# DATA-4380
# Dr. Farbin
# Homework #1
# 6/11/2025

# %% [markdown]
# ### Homework - Command Shell

# %% [markdown]
# #### Initial Setup:

# %% [markdown]
# - Initial setup included installation of Kaggle's API, a Python  `venv` virtual environment, jupyter, and other software packages for now via the `apt`
# package manager.
# - Github authentication was already setup locally on local laptop/workstation machine.
# - Running symbolic links for Kaggle data before doing the exercise runs.
# - Setup up `src` source directory with subdirectories.
# - setup a `.gitignore` to suppress pushing anything not wanted to be pushed remotely to Github repository.

# %% [markdown]
# ![unix-shell-hw.png](attachment:13b88626-5da3-4fc2-be10-abfeaf20e08e.png)

# %% [markdown]
# #### Exercises:

# %%
"""
1. Organize your dataset directory. Make a new directory for the original zip files, and move the files there. In case you accidentally mess up 
one of the CSV files, you'll be able unzip the data again. 
"""
mkdir src
cd /home/rc/DATA4380.Summer.2025/src
mkdir data homework projects
cd /home/rc/DATA4380.Summer.2025/src/data
mkdir zips

# %%
"""
Downloaded data. Kaggle competition data had to be manually downloaded from Microsoft SharePoint. SharePoint does have an API.
"""
# Competition data need authentication and invitation. Manually downloaded.
kaggle competitions download -c diabetes-prediction-with-nn
kaggle competitions download -c used-car-price-prediction-competition
kaggle competitions download -c business-research-methods-world-university-rankings

# Kaggle's /datasets URL's ran to download data below via Kaggle's API 
kaggle datasets download -d rishidamarla/heart-disease-prediction
kaggle datasets download -d yasserh/housing-prices-dataset
kaggle datasets download -d simtoor/mall-customers
kaggle datasets download -d m5anas/cancer-patient-data-sets

# %%
"""
2. The "diabetes_prediction_dataset.csv" file has a lot of entries. Create 3 new CSV files, each with about 1/3 of the data.
"""

# %%
"""
3. Create 2 new CSV files from Heart_Disease_Prediction.csv, one containing rows with "Presence" label and another with "Absence" label. Make sure 
that the first line of each file contains the field names.
"""

# %%
"""
4. What fraction of cars in car_web_scraped_dataset.csv have had no accidents?
"""

# %%
"""
5. Make the following replacements in Housing.csv, output the result into a new CSV:
- yes -> 1
- no -> 0
- unfurnished -> 0
- furnished -> 1
- semi-furnished -> 2
"""

# %%
"""
6. Create a new CSV files from Mall_Customers, removing "CustomerID" column.
"""

# %%
"""
7. Create a new file that contains the sum of the following fields for each row:
- Research Quality Score
- Industry Score
- International Outlook
- Research Environment Score
"""

# %%
"""
8. Sort the cancer patient data sets.csv file by age. Make sure the output is a readable CSV file.
"""

# %% [markdown]
# #### References:

# %% [markdown]
# - The GNU Project - [Bash Documentation/Reference Manual](https://www.gnu.org/savannah-checkouts/gnu/bash/manual/bash.html)
# - UCL - [Introduction to the UNIX shell](https://github-pages.ucl.ac.uk/RCPSTrainingMaterials/HPCandHTCusingLegion/2_intro_to_shell.html)
# - Station X - [Unix Commands Cheat Sheet: All the Commands You Need](https://www.stationx.net/unix-commands-cheat-sheet/)
# - GitHub - [GitHub CLI Manual](https://cli.github.com/manual/)
# - OpenAI - [link](https://openai.com/)
# - Google - [link](https://www.google.com/)
